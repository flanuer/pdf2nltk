# %%
from bs4 import BeautifulSoup 
import urllib.request 
import nltk 
from nltk.corpus import stopwords 
response = urllib.request.urlopen('https://www.whoi.edu/website/redtide/research/publications-reports/national/') 
html = response.read() 
soup = BeautifulSoup(html,"html5lib") 
text = soup.get_text(strip=True) 
tokens = [t for t in text.split()] 
clean_tokens = tokens[:] 
sr = stopwords.words('english') 
for token in tokens: 
    if token in stopwords.words('english'): 
        clean_tokens.remove(token) 
freq = nltk.FreqDist(clean_tokens) 
for key,val in freq.items(): 
    print (str(key) + ':' + str(val))
# Out:
# National:6
# Publications:4
# Reports:1
# ::1
# Red:1
# Tide(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start'::1
# new:1
# Date().getTime(),event:'gtm.js'});var:1
# f=d.getElementsByTagName(s)[0],:1
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=:1
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);:1
# })(window,document,'script','dataLayer','GTM-PMV284L');HomeSpeciesBy:1
# NameBy:1
# LocationBy:1
# SyndromeLife:1
# CycleImpactsHuman:1
# HealthWildlifeEcosystemsSocioeconomicFreshwaterRegionsDistribution:1
# -:2
# U.S.Distribution:1
# WorldMapsResearchProgramsPublications:1
# /:3
# ReportsProjectsResourcesNational:1
# ResourcesInternational:1
# ResourcesStates,:1
# Tribes,:1
# RegionsFact:1
# sheets:1
# cardsToxin:1
# HotlinesAnnouncementsFAQsPhotosASPCFPDSPNSPPSPFreshwater:1
# HABsMacroalgal:1
# BloomsBloomsImpactsOtherLinksResearchProgramsPublications:1
# ReportsNational:2
# ReportsInternational:1
# ProceedingsInternational:1
# ProceedingsOther:1
# PublicationsProjectsNational:1
# ReportsHarmful:1
# Algal:15
# Blooms:4
# Hypoxia:2
# Comprehensive:1
# Research:9
# Plan:1
# Action:1
# Strategy::1
# An:1
# Interagency:2
# ReportA:1
# report:1
# Congress:1
# produced:1
# Working:1
# Group:1
# Harmful:12
# Bloom:3
# Control:1
# Act:1
# (IWG-HABHRCA).20163.7MB:1
# PDFHAB:1
# RDDTT-:1
# Research,:1
# Development,:1
# Demonstration,:1
# &:2
# Technology:1
# TransferDortch,:1
# Q.,:4
# Anderson,:2
# D.M.,:1
# Ayres,:1
# D.L.,:1
# Glibert,:1
# P.M.:2
# (Eds.)5.7:1
# MB:1
# PDFScientific:2
# Assessment:3
# Marine:1
# BloomsLopez,:2
# C.B.,:3
# Dortch,:3
# Jewett,:2
# E.B.,:3
# Garrison,:2
# D.:4
# (Eds.)20083.7MB:1
# Freshwater:1
# Walton,:1
# B.T.,:1
# Hudnell,:1
# H.K.20083.4MB:1
# PDFHarmful:4
# Management:1
# Response::3
# PlanJewett,:1
# Lopez,:1
# Etheridge,:1
# S.M,:1
# Backer,:1
# L.C.:1
# (Eds)20086.9MB:1
# PDFInteragency:1
